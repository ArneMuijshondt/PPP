# %% [markdown]
# # Create a CNN to classify Cifar-10
#
# Learn about Cifar-10 here: https://www.cs.toronto.edu/~kriz/cifar.html
#
# In class you saw how to build a Convolutional Neural Network that classified Fashion MNIST. Take what you learned to build a CNN that recognizes the 10 classes of CIFAR. It will be a similar network, but there are some key differences you'll need to take into account.
#
# First, while MNIST were 28x28 monochome images (1 color channel), CIFAR are 32x32 color images (3 color channels).
#
# Second, MNIST images are simple, containing just the object, centered in the image, with no background. CIFAR ones can have the object with a background -- for example airplanes might have a cloudy sky behind them! As such you should expect your accuracy to be a bit lower.
#
# We start by setting up the problem for you.

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# We then definte some of the model for you but leave most of it for you to fill in!
#
# *A hint: your model may want to learn some high level features and then classify them.*

# %%
FIRST_LAYER = layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3))
HIDDEN_LAYER_TYPE_1 = layers.MaxPooling2D((2, 2))
HIDDEN_LAYER_TYPE_2 = layers.Conv2D(64, (3, 3), activation='relu')
HIDDEN_LAYER_TYPE_3 = layers.MaxPooling2D((2, 2))
HIDDEN_LAYER_TYPE_4 = layers.Conv2D(64, (3, 3), activation='relu')
HIDDEN_LAYER_TYPE_5 = layers.Dense(64, activation='relu')
LAST_LAYER = layers.Dense(10)

model = models.Sequential([
       FIRST_LAYER,
       HIDDEN_LAYER_TYPE_1,
       HIDDEN_LAYER_TYPE_2,
       HIDDEN_LAYER_TYPE_3,
       HIDDEN_LAYER_TYPE_4,
       layers.Flatten(),
       HIDDEN_LAYER_TYPE_5,
       LAST_LAYER,
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# You then need to define loss function. And you can then train your model. Once training is done you'll see a plot of training and validation accuracy. You'll know you have a reasonable model with a reasonable loss funciton if your final training accuracy ends up in the 70s (or possibly higher).
#
# *A hint: your model may want to learn different categories.*

# %%
LOSS = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
NUM_EPOCHS = 20 #You can change this value if you like to experiment with it to get better accuracy

# Compile the model
model.compile(optimizer='sgd',
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.1874 - loss: 2.1883 - val_accuracy: 0.2996 - val_loss: 1.9647
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3714 - loss: 1.7432 - val_accuracy: 0.4166 - val_loss: 1.5849
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.4540 - loss: 1.5083 - val_accuracy: 0.4689 - val_loss: 1.4684
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4976 - loss: 1.3894 - val_accuracy: 0.4757 - val_loss: 1.4930
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5379 - loss: 1.2991 - val_accuracy: 0.5494 - val_loss: 1.2446
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.5640 - loss: 1.2282 - val_accuracy: 0.5766 - val_loss: 1.1915
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5858 - loss: 1.1689 - val_accuracy: 0.5582 - val_loss: 1.2126
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6105 - loss: 1.1059 - val_accuracy: 0.5896 - val_loss: 1.1642
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6290 - loss: 1.0522 - val_accuracy: 0.6083 - val_loss: 1.1111
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6518 - loss: 1.0000 - val_accuracy: 0.6352 - val_loss: 1.0318
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6612 - loss: 0.9620 - val_accuracy: 0.6120 - val_loss: 1.0788
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6790 - loss: 0.9259 - val_accuracy: 0.6222 - val_loss: 1.0921
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6847 - loss: 0.8983 - val_accuracy: 0.6617 - val_loss: 0.9677
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.7015 - loss: 0.8581 - val_accuracy: 0.6626 - val_loss: 0.9754
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7129 - loss: 0.8304 - val_accuracy: 0.6751 - val_loss: 0.9436
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7246 - loss: 0.8014 - val_accuracy: 0.6317 - val_loss: 1.0757
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7336 - loss: 0.7662 - val_accuracy: 0.6479 - val_loss: 1.0360
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.7410 - loss: 0.7475 - val_accuracy: 0.6501 - val_loss: 1.0253
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7506 - loss: 0.7210 - val_accuracy: 0.6790 - val_loss: 0.9624
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7573 - loss: 0.6977 - val_accuracy: 0.6963 - val_loss: 0.8882

# %% [markdown]
# Finally, pick a better optimizer. And re-train your model. You'll know you have a reasonable model with a reasonable loss funciton and optimizer if your final training accuracy ends up in the 80s (or possibly higher).
#
# *A hint: your model may want to learn adaptively.*

# %%
OPTIMIZER = tf.keras.optimizers.Adam()

# Compile the model
model.compile(optimizer=OPTIMIZER,
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.6937 - loss: 0.8672 - val_accuracy: 0.6683 - val_loss: 0.9389
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7283 - loss: 0.7827 - val_accuracy: 0.6771 - val_loss: 0.9319
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7578 - loss: 0.6891 - val_accuracy: 0.6938 - val_loss: 0.8930
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7831 - loss: 0.6092 - val_accuracy: 0.7029 - val_loss: 0.8878
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8084 - loss: 0.5409 - val_accuracy: 0.7022 - val_loss: 0.9023
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8294 - loss: 0.4827 - val_accuracy: 0.7099 - val_loss: 0.9172
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8515 - loss: 0.4179 - val_accuracy: 0.7080 - val_loss: 0.9849
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8721 - loss: 0.3684 - val_accuracy: 0.6990 - val_loss: 0.9906
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8814 - loss: 0.3288 - val_accuracy: 0.7040 - val_loss: 1.0591
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8971 - loss: 0.2893 - val_accuracy: 0.6991 - val_loss: 1.1141
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9090 - loss: 0.2520 - val_accuracy: 0.7029 - val_loss: 1.1868
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9227 - loss: 0.2177 - val_accuracy: 0.6956 - val_loss: 1.2779
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9240 - loss: 0.2091 - val_accuracy: 0.7014 - val_loss: 1.3878
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9333 - loss: 0.1852 - val_accuracy: 0.6885 - val_loss: 1.4962
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9386 - loss: 0.1692 - val_accuracy: 0.6907 - val_loss: 1.5284
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9448 - loss: 0.1560 - val_accuracy: 0.6841 - val_loss: 1.6146
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9476 - loss: 0.1506 - val_accuracy: 0.6948 - val_loss: 1.6401
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9524 - loss: 0.1354 - val_accuracy: 0.6882 - val_loss: 1.7718
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9516 - loss: 0.1379 - val_accuracy: 0.6898 - val_loss: 1.8467
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9519 - loss: 0.1315 - val_accuracy: 0.6915 - val_loss: 1.8127

# %% [markdown]
# There is an absolutely massive difference, but curiously there is only a small difference in validation, it did get to a good accuracy way quicker, so you would actually need fewer epochs, yay Adam!
